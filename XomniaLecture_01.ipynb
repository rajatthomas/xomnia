# %% [markdown]
# # Introduction to Deep Learning
# ***
# ![nn.png](attachment:nn.png)
#
# ## Today's Agenda - 9:30 - 13:00
#
# -  ### Introducing <font color = red> _each other_ </font>
# -  ### Understand your hopes and aspirations for deep learning (examples)
# -  ### Recap our understanding of the deep world
# -  ### Diving <font color = red> __deep__ </font>
